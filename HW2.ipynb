# %% [markdown]
# <!--
# # Devoir maison II : Traitement de données avec R
# -->
#
# <center>
#     <h1>Devoir maison II : Traitement de données avec R</h1>
# </center>
#
# <center style='padding: 30px'>
#     Télécharger ce document au format
#     <a href="HW2.html" download>HTML</a> ou
#     <a href="HW2.ipynb" download>Jupyter</a>.
# </center>
#
# <strong>INSTRUCTIONS. <span style='color: darkorange'>Merci de les lire attentivement.</span></strong>
#
# * Utiliser ce document comme modèle.
#
# * Lorsque les questions ne demandent pas de code, on donnera la réponse dans une cellule de texte.
#
# * Un commentaire doit accompagner tout code complexe.
#
# * Chaque question doit faire l’objet d’une ou plusieurs nouvelles cellules de texte ou de code.
#
# * Certaines questions supposent que l’on ait répondu à une ou plusieurs questions précédentes. Si toutefois vous êtes bloqué.e sur une question, on peut supposer que les fonctions nécessaires sont implémentées et que les données ont le bon format.
#
# * Les noms de variable ou de colonne doivent être en anglais (sauf pour les variables courtes comme `i`, `k` ou `x`).
#
# * Penser à annoter les graphiques.
#
# <strong>CONSEILS. <span style='color: darkorange'>Merci de les lire attentivement.</span></strong>
#
# * Il s’agit aussi d’un exercice de communication : votre document doit permettre à un-e lecteur-ice
#   autre que vous-même de comprendre aisément votre démarche donc incluez autant de cellules de texte que nécessaire (tout en restant concis).

# %% [markdown]
# ## Partie 1 : Analyser les données COVID-19 \[8 points]
#
# Les <a href="https://www.data.gouv.fr/fr/datasets/synthese-des-indicateurs-de-suivi-de-lepidemie-covid-19/" target="_blank">indicateurs de l'épidémie de COVID-19</a> sont mis à jour et publiés sur `data.gouv.fr`. Deux jeux de données sont disponibles : le premier contient des informations par département et le second des données agrégées sur l'ensemble de la France. On considère ici le second jeu de données **concernant toute la France**.
#
# **QUESTION 1.** Importer les données dans une variable `covid`. (Indication : il n'est pas nécessaire de télécharger le fichier.)

# %%
# Code goes here

# %% [markdown]
# **QUESTION 2.** Quelles sont les dimensions des données: combien de lignes et combien de colonnes?

# %%
# Code goes here

# %% [markdown]
# **QUESTION 3.** Sur la page `data.gouv.fr`, deux commentaires indiquent :
#
# * « La ligne pour le 2021-03-12 est en double »
# * « Il semblerait que toutes les données antérieures au 15/03/2021 aient été doublées. »
#
# Vérifier si oui ou non c'est le cas.

# %%
# Code goes here

# %% [markdown]
# *Les explications et la conclusion vont ici*

# %% [markdown]
# **QUESTION 4.** À l'aide de la bibliothèque `dplyr`,
# modifier `covid` de sorte à ne garder que les colonnes suivantes et en renommant certaines des colonnes:
#
# * `date` (sans renommer)
# * `tx_pos`   devient `positivity_rate`
# * `tx_incid` devient `incidence_rate`
# * `R` (sans renommer)
# * `hosp`     devient `admissions_num`

# %%
# Code goes here

# %% [markdown]
# **QUESTION 5.**
#
# * Compléter la définition de `count_na()`, qui compte le nombre de valeurs `NA` présentes dans le vecteur passé en argument
# * Expliquer son fonctionnement dans une cellule de texte
# * Compléter la définition de `pc_na()` donnant le pourcentage de valeurs `NA` (cette fonction utilise `count_na()`)
#
# ```R
# count_na(c(NA, 1, NA, 2, NA)) # Returns 3
# pc_na(c(NA, 1, NA, 2, NA))    # Returns 60
# ```

# %%
count_na = function (x) {
    # ...
}

# %% [markdown]
# *Votre réponse ici*

# %%
pc_na = function (x) {
    # ...
}

# %% [markdown]
# **QUESTION 6.** Utiliser la fonction `pc_na()` pour déterminer le pourcentage de valeurs manquantes dans chaque champ du jeu de données dans un appel à `summarise()`.

# %%
# Code goes here

# %% [markdown]
# **QUESTION 7.** Représenter graphiquement l'évolution du nombre de personnes hospitalisées en fonction du temps.

# %% [markdown]
# **QUESTION 8.** Taux de reproduction de l'épidémie.
#
# 1. Représenter graphiquement l'évolution du coefficient $R$ en fonction du temps.
#
# 2. En raison de valeurs manquantes, vous pourriez voir apparaître un message d'avertissement « Removed 82 row(s) containing missing values (geom_path). » Comment faire pour que ce message n'apparaisse pas ?

# %%
# Code goes here

# %% [markdown]
# ## Partie 2 : Calcul de notes \[7 points]

# %% [markdown]
# Il s'agit ici de calculer les moyennes d'élèves d'un certain nombre de classes.  Utiliser les données du fichier <code><a href="marks.csv" download>marks.csv</a></code>. Les entêtes correspondent à `class` nom de la classe,
# `last` nom de famille,
# `first` prénom,
# `maths1` note au premier devoir de maths,
# `maths2` note au second devoir de maths,
# `physics` note au devoir de physique,
# `composition` note de dissertation
#
# Répondre aux questions suivantes.

# %% [markdown]
# **QUESTION 9.** Quelle est la taille de chaque classe?

# %%
# Code goes here

# %% [markdown]
# **QUESTION 10.** Convertir le cadre de données dans un format long:
#
# | class | last | first | name | value |
# |-------|------|-------|---------|------|
# | A | AVRIL | DAVID | maths1 | 14 |
# | A | AVRIL | DAVID | maths2 | 16 |
# | A | AVRIL | DAVID | physics | 12 |
# | A | AVRIL | DAVID | composition | 8 |
# | etc. |

# %%
# Code goes here

# %% [markdown]
# **QUESTION 11.** Modifier la colonne `name` à l'aide de `ifelse()`, `str_end()` et `paste()` pour obtenir
#
# | class | last | first | name | value |
# |-------|------|-------|---------|------|
# | A | AVRIL | DAVID | maths1 | 14 |
# | A | AVRIL | DAVID | maths2 | 16 |
# | A | AVRIL | DAVID | physics1 | 12 |
# | A | AVRIL | DAVID | composition1 | 8 |
# | etc. |
#
# (L'ordre des lignes n'est pas important.)

# %%
# Code goes here

# %% [markdown]
# **QUESTION 12.** Séparer les informations de `name` dans deux colonnes distinctes `subject` et `test` à l'aide de la commande
#
# ```R
# df %>% extract(name, '^(\\w+)(\\d)$', into=c('subject', 'test'))
# ```
#
# <!-- $'
# ```
# -->
#
# et renommer la colonne `value` afin d'obtenir
#
# | class | last | first | subject | test | marks |
# |-------|------|-------|---------|------|-------|
# | A | AVRIL | DAVID | maths | 1 | 14 |
# | A | AVRIL | DAVID | maths | 2 | 16 |
# | A | AVRIL | DAVID | physics | 1 | 12 |
# | A | AVRIL | DAVID | composition | 1 | 8 |
# | etc.
#
# (L'ordre des lignes n'est pas important.)
#
# Expliquer `'^(\\w+)(\\d)$'`.

# %%
# Code goes here

# %% [markdown]
# *Explications*

# %% [markdown]
# **QUESTION 13.** Calculer une moyenne par discipline :
#
# | class | last | first | subject |  marks |
# |-------|------|-------|---------|--------|
# | A | AVRIL | DAVID | maths | 15 |
# | A | AVRIL | DAVID | physics | 12 |
# | A | AVRIL | DAVID | composition | 8 |
# | etc.
#
# (L'ordre des lignes n'est pas important.)
#
# ATTENTION : La moyenne est calculée en ne tenant compte que des devoirs pour lesquels une note est disponible et sans pondération particulière. (Si aucune note n'est disponible pour une discipline, `NA` doit être renseigné.)
#
# Indication : Consulter la documentation de la fonction `mean()`.

# %%
# Code goes here

# %% [markdown]
# **QUESTION 14.** Calculer une moyenne générale :
#
# | class | last | first | average |
# |-------|------|-------|-------|
# | A | AVRIL | DAVID | 12 |
# | A | AYALA | SYLVIE | 15 |
# | A | BRUNAUD | WILLIAM | 13 |
# | A | DUMONT | EDWARD | 13 |
# | etc.
#
# (L'ordre n'est pas important.)
#
# ATTENTION :
#
# 1. Pour que la moyenne générale puisse être calculée, une note doit être disponible pour chaque disponible, sinon `NA` doit être retourné.
#
# 2. Arrondir la moyenne générale à l'entier supérieur avec `ceiling()`.

# %%
# Code goes here

# %% [markdown]
# **QUESTION 15.** Combien de personnes n'ont pas de moyenne générale et doivent être évaluées à nouveau ?

# %%
# Code goes here

# %% [markdown]
# **QUESTION 16.** Combien de personnes ayant eu une moyenne générale ont une moyenne strictement inférieure à 10 ?

# %%
# Code goes here

# %% [markdown]
# ## Partie 3 : Démographie de la France métropolitaine \[5 points]
#
# Le jeu de données <code><a href="valeurs_mensuelles.csv" download>valeurs_mensuelles.csv</a></code> est mis à jour par l'INSEE <a href="https://www.insee.fr/fr/statistiques/series/103088458" target="_blank">Population et structure de la population</a>. Le jeu de données peut être lu à l'aide de la commande suivante :

# %%
raw = read_csv2('valeurs_mensuelles.csv')

# %% [markdown]
# Le format du fichier n'est pas approprié pour les analyses, les objectifs de cette partie sont de former deux jeux de données.
#
# 1. Un jeu de données mensuelles `mdat`
#
# <table class="dataframe">
# <caption>A tibble: 6 × 4</caption>
# <thead>
# 	<tr><th scope="col">date</th><th scope="col">population</th><th scope="col">monthly_increase</th><th scope="col">year</th></tr>
# 	<tr><th scope="col">&lt;date&gt;</th><th scope="col">&lt;dbl&gt;</th><th scope="col">&lt;dbl&gt;</th><th scope="col">&lt;date&gt;</th></tr>
# </thead>
# <tbody>
# 	<tr><td>1975-01-01</td><td>52600000</td><td> 8000</td><td>1975-01-01</td></tr>
# 	<tr><td>1975-02-01</td><td>52608000</td><td>15000</td><td>1975-01-01</td></tr>
# 	<tr><td>1975-03-01</td><td>52623000</td><td>17000</td><td>1975-01-01</td></tr>
# 	<tr><td>1975-04-01</td><td>52640000</td><td>22000</td><td>1975-01-01</td></tr>
# 	<tr><td>1975-05-01</td><td>52662000</td><td>26000</td><td>1975-01-01</td></tr>
# 	<tr><td>1975-06-01</td><td>52688000</td><td>23000</td><td>1975-01-01</td></tr>
# 	<tr><td>etc.</td><td>etc.</td><td>etc.</td><td>etc.</td></tr>
#     </tbody>
# </table>
#
# 2. Un jeu de données annuelles `ydat`
#
# <table class="dataframe">
# <caption>A tibble: 6 × 2</caption>
# <thead>
# 	<tr><th scope="col">year</th><th scope="col">yearly_increase</th></tr>
# 	<tr><th scope="col">&lt;date&gt;</th><th scope="col">&lt;dbl&gt;</th></tr>
# </thead>
# <tbody>
# 	<tr><td>1975-01-01</td><td>198000</td></tr>
# 	<tr><td>1976-01-01</td><td>221000</td></tr>
# 	<tr><td>1977-01-01</td><td>253000</td></tr>
# 	<tr><td>1978-01-01</td><td>209000</td></tr>
# 	<tr><td>1979-01-01</td><td>250000</td></tr>
# 	<tr><td>1980-01-01</td><td>298000</td></tr>
# 	<tr><td>etc.</td><td>etc.</td></tr>
# </tbody>
# </table>
#
# ATTENTION : Prêter attention à la classe des vecteurs colonnes.
#
# **QUESTION 17.** Produire les jeux de données `mdat` et `ydat`.
#
# **QUESTION 18.** Combien de mois a-t-on pu observer un solde strictement négatif ?
#
# **QUESTION 19.** Croiser les jeux de données de façon à pouvoir réaliser un graphique du solde démographique.
#
# Indication : L'utilisation de la bibliothèque `lubridate` pourra simplifier certaines opérations.

# %%
ggplot(combined, aes(date, value, colour=name)) +
    geom_line() +
    labs(title='Population increase in metropolitan France from 1975 to 2020',
         x='Year',
         y='Monthly population increase',
         colour='Estimation') +
    theme(legend.position='top') +
    scale_color_manual(values=c('gray', 'black'),
                       labels = c('Monthly', 'Yearly average'))
# Out:
# plot without title
